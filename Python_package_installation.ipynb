# %% [markdown]
# # Installing Packages using Pip (Python's Package Manager)

# %%
# https://github.com/sckott/habanero
# %pip install habanero
# Out:
# ...
#   Using cached habanero-0.7.4-py2.py3-none-any.whl (35 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Testing habanero Library

# %%
from habanero import Crossref
cr = Crossref()
x = cr.works(query = "ecology")
x['message']
# Out:
# {'facets': {},
#  'total-results': 379003,
#  'items': [{'indexed': {'date-parts': [[2020, 7, 28]],
#     'date-time': '2020-07-28T08:00:16Z',
#     'timestamp': 1595923216690},
#    'reference-count': 0,
#    'publisher': 'Oxford University Press',
#    'isbn-type': [{'value': '9780199830060', 'type': 'electronic'}],
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
# ...
